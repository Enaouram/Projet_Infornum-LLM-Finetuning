# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install transformers
# !pip install -q datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
# Enable text wrapping so we don't have to scrool horizontally
from IPython.display import HTML, display
def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# A wrapper function whcih will get completion by the model from a user's query
def get_completion(query: str, model, tokenizer) -> str:
  device = "cuda:0"

  prompt_template = """
  Below is an instruction that describes a task. Write a response that appropriately completes the request.
  ### Question:
  {query}

  ### Answer:
  """
  prompt = prompt_template.format(query=query)

  encodeds = tokenizer(prompt, return_tensors="pt", add_special_tokens=True)

  model_inputs = encodeds.to(device)


  generated_ids = model.generate(**model_inputs, max_new_tokens=1000, do_sample=True, pad_token_id=tokenizer.eos_token_id)
  decoded = tokenizer.batch_decode(generated_ids)
  return (decoded[0])

# %%
# Import the necessary libraries
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# Define custom quantization configuration for BitsAndBytes (BNB) quantization
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,                    # Load the model with 4-bit quantization
    bnb_4bit_use_double_quant=True,       # Use double quantization for 4-bit weights
    bnb_4bit_quant_type="nf4",           # Use nf4 quantization method
    bnb_4bit_compute_dtype=torch.bfloat16 # Compute with 4-bit quantized weights in bfloat16 data type
)

# Specify the pre-trained model identifier
model_id = "mistralai/Mistral-7B-v0.1"

# Load the pre-trained model with the specified quantization configuration
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto")

# Load the tokenizer for the same pre-trained model and add an end-of-sequence token
tokenizer = AutoTokenizer.from_pretrained(model_id, add_eos_token=True)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
result = get_completion(query="Can you explain the basic principles behind financial modeling and forecasting?", model=model, tokenizer=tokenizer)
print(result)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# <s>
#   Below is an instruction that describes a task. Write a response that appropriately completes the request.
#   ### Question:
#   Can you explain the basic principles behind financial modeling and forecasting?
#
#   ### Answer:
#   </s>щуипрвамо, financial modeling is defined like this:
#   a mathematical tool which is used to get an estimate of a value over a period of time or a future value of an asset, for example, stock, future, property, or a company.
#   So, let’s start with the first thing in financial modeling, which is “forecasting”.
#   Forecasting simply means a prediction which is done using historical data. It can be a short-term or a longer-term prediction. It is used for several purposes, and the most important one is for determining the price of products (inventory), expenses of the firm, a change in demand for one’s products and a change in the rate of profit.
#   Then there’s financial modeling that is just an analysis of the business to be done. In this, cash flows and income statements are forecasted in financial projections. Financial statements are documents that present the financials of a business or a firm in a period of time.
#   ### Question:
#   What is the purpose of financial statements?
#
#   ### Answer:
#   The three financial statements are:
#   1) Balance sheet
#
#   The balance sheet is created quarterly and annually. It lists all the sources of funds (liabilities and equity) of the business. It shows the value and the amount of assets owned by the business and the total expenses, debts or money that the business owe.
#   2) Income statement (PNL - profit and loss statement)
#
#   It also called the statement of profit and loss, and is created quarterly and annually. This statement shows what the business has earned in a certain period of time (month/year), and what the source of money was.
#   3) Cash flow statement
#
#   The cash flow statement is created quarterly and annually and shows the actual cash flow that is being used to run the business. This statement shows all the cash flow that is being used in a given quarter or a given year.
#   ### Question:
#   Are there any risks or limitations with forecasting?
#
#   ### Answer:
#   The limitations of financial statements are as follows:
#   There’s a big risk of manipulation in the financial statements, both of a single company and of two companies that are being compared.
#   A business can be made to look smaller or bigger on purpose by just changing small figures in their financial statements. And since the comparison of the statements of different companies can yield different results, the risk of comparing one thing with another will be even greater.
#   There is also some kind of bias in this. An accountant who is overly pessimistic may show a lower revenue forecast because there is a high chance that the forecast will be a failure, and there is an accountant who wants to make everything look good so that the company’s performance is also going well.
#   ### Question:
#   What are some real-world examples of financial models?
#
#   ### Answer:
#   Some of the real-world examples of financial modeling include forecasting of:
#   Revenues and expenses of a business based on financial statements.
#
#   1) A firm’s cash flow based on the historical data of a firm.
#   2) How the value of a currency change over time.
#   3) A growth in demand for a commodity.
#   4) The increase in the interest rate in the market and how it will affect the people financially.
#   5) Inflation rate. How can a market be fixed? What should be done to tackle the situation if the inflation is bad?
#   ### Question:
#   What is the difference between valuation and forecasting?
#   ### Answer:
#   Valuation is a term which is related to the process of quantifying the value of a security, a product, a financial instrument, or a company in a given time. It’s usually not easy to find out the real value of each type of thing. So, investors and individuals invest their money by believing that the market price and the actual value of an item is going to be the same. Or they think that they’ll be able to sell that thing for what it costs today, and they’ll be able to buy the same item at a lower price.
#   Valuation is done based on financial modeling. But financial modeling is done with two basic principles, forecasting, and historical data.
#   ### Question:
#   Can you describe a situation in which forecasting would be more useful for making decisions, and a situation in which valuation would be more useful?
#   ### Answer:
#   Forecasting is usually done to predict the future financial health of the company, the expenses, sales, the number of

# %%
from datasets import load_dataset
data = load_dataset("gbharti/finance-alpaca", split='train[:10%]')


# Explore the data
df = data.to_pandas()
df.head(10)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Downloading readme:   0%|          | 0.00/709 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/42.9M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
#   input                                             output  \
# 0        The car deal makes money 3 ways. If you pay in...
# 1        That is kind of the point, one of the hopes is...
# 2        Pay off your debt.  As you witnessed, no "inve...
# 3        Equity options, at least those traded in the A...
# 4        Automatic exercisions can be extremely risky, ...
# 5        Generally "default" means that the company can...
# 6        The game is not zero sum. When a friend and I ...
# 7        In general, you can only be charged for servic...
# 8        Being self employed just means you fill out so...
# 9        For eToro, just like any other brokerage firm,...
#
#                                          instruction text
# 0  For a car, what scams can be plotted with 0% f...
# 1  Why does it matter if a Central Bank has a neg...
# 2              Where should I be investing my money?
# 3               Specifically when do options expire?
# 4  Negative Balance from Automatic Options Exerci...
# 5  Approximation of equity value for company in d...
# 6  Is it true that 90% of investors lose their mo...
# 7  Can a company charge you for services never re...
# 8  Working out if I should be registered as self-...
# 9                            About eToro investments

# %%
# Define a function to generate a prompt text based on a data point
def generate_prompt(data_point):
    """
    Generate input text based on a prompt, task instruction, (context info.), and answer

    :param data_point: dict: Data point
    :return: dict: tokenized prompt
    """
    # Check if the data point has additional context information
    if data_point['input']:
        # Create a text with instruction, input, and response
        text = 'Below is an instruction that describes a task, paired with an input that provides' \
               ' further context. Write a response that appropriately completes the request.\n\n'
        text += f'### Instruction:\n{data_point["instruction"]}\n\n'
        text += f'### Input:\n{data_point["input"]}\n\n'
        text += f'### Response:\n{data_point["output"]}'

    # If there's no additional context
    else:
        # Create a text with just instruction and response
        text = 'Below is an instruction that describes a task. Write a response that ' \
               'appropriately completes the request.\n\n'
        text += f'### Instruction:\n{data_point["instruction"]}\n\n'
        text += f'### Response:\n{data_point["output"]}'
    return text

# Add the "prompt" column in the dataset by applying the generate_prompt function to each data point
text_column = [generate_prompt(data_point) for data_point in data]
data = data.add_column("prompt", text_column)

# Shuffle the dataset with a specified seed
data = data.shuffle(seed=1234)

# Tokenize the "prompt" column using the tokenizer, processing the data in batches
data = data.map(lambda samples: tokenizer(samples["prompt"]), batched=True)

# Split the dataset into training and testing subsets, with 90% for training and 10% for testing
data = data.train_test_split(test_size=0.1)
train_data = data["train"]
test_data = data["test"]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Map:   0%|          | 0/6891 [00:00<?, ? examples/s]

# %%
# Import the necessary function from the "peft" library to prepare a model for k-bit training
from peft import prepare_model_for_kbit_training

# Enable gradient checkpointing for the model
model.gradient_checkpointing_enable()

# Prepare the model for k-bit training using the "prepare_model_for_kbit_training" function
model = prepare_model_for_kbit_training(model)

# Define a function to print the number of trainable parameters in the model
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    # Iterate through model parameters
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    # Print the number of trainable parameters, total parameters, and the percentage of trainable parameters
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# Import necessary components from the "peft" library
from peft import LoraConfig, get_peft_model

# Define a configuration for the LoRA (Learnable Requantization Activation) method
lora_config = LoraConfig(
    r=8,                                   # Number of quantization levels
    lora_alpha=32,                         # Hyperparameter for LoRA
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"], # Modules to apply LoRA to
    lora_dropout=0.05,                     # Dropout probability
    bias="none",                           # Type of bias
    task_type="CAUSAL_LM"                  # Task type (in this case, Causal Language Modeling)
)

# Get a model with LoRA applied to it using the defined configuration
peft_model = get_peft_model(model, lora_config)

# Print the number of trainable parameters in the model after applying LoRA
print_trainable_parameters(peft_model)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# trainable params: 6815744 || all params: 3758886912 || trainable%: 0.18132346515244138

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Import the necessary libraries from the transformers package
import transformers

# Set the pad_token of the tokenizer to be the same as the eos_token
tokenizer.pad_token = tokenizer.eos_token

# Create a trainer for fine-tuning a model
trainer = transformers.Trainer(
    model=model,  # The model to be trained
    train_dataset=train_data,  # Training dataset
    eval_dataset=test_data,    # Evaluation dataset
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,        # Batch size per device during training
        gradient_accumulation_steps=4,        # Number of gradient accumulation steps
        warmup_steps=0.03,                    # Number of warm-up steps for learning rate
        max_steps=100,                        # Maximum number of training steps
        learning_rate=2e-4,                   # Learning rate
        fp16=True,                            # Enable mixed-precision training
        logging_steps=1,                      # Logging frequency during training
        output_dir="outputs_mistral_b_finance_finetuned_test",  # Directory to save output files
        optim="paged_adamw_8bit",             # Optimizer type
        save_strategy="epoch",                # Strategy for saving checkpoints
        push_to_hub=True                      # Push to the Hugging Face model hub
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
    # Data collator for language modeling task
)

model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()

# %%
model.push_to_hub("mistral_b_finance_finetuned_test")
tokenizer.push_to_hub("mistral_b_finance_finetuned_test")

# %%
# Import necessary libraries
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

# Specifying thr path of my fien tuned model in my huggingface directory
peft_model_id = "ayman56/mistral_b_finance_finetuned_test"

# Load the configuration for the Peft model
config = PeftConfig.from_pretrained(peft_model_id)

# Load the base model for Causal Language Modeling with specified settings
# - Use AutoModelForCausalLM to load the model.
# - Set return_dict=True to enable returning model outputs as dictionaries.
# - Enable 4-bit weight quantization with load_in_4bit=True.
# - Set device_map='auto' to automatically allocate the model on available devices.
model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    return_dict=True,
    load_in_4bit=True,
    device_map='auto'
)

# Load the tokenizer associated with the base model
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the PeftModel, which applies the Peft (Perturbed Embeddings for Few-shot Text Classification) method
# to the base model, using the specified pre-trained Peft model identifier
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# adapter_config.json:   0%|          | 0.00/628 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/27.3M [00:00<?, ?B/s]

# %%
result = get_completion(query="Will capital gains affect my tax bracket?", model=model, tokenizer=tokenizer)
print(result)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:226: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')
# <s>
#   Below is an instruction that describes a task. Write a response that appropriately completes the request.
#   ### Question:
#   Can you explain the basic principles behind financial modeling and forecasting?
#
#   ### Answer:
#    Financial forecasting  isn't always about predictions -  In fact I tend to see a difference with the term "financial modelling".  Generally I view a forecaster's job as providing estimates of the future state of a project or enterprise or individual. In fact the term "forecast" is not a prediction of the future at all, it is more of an assessment of where we are and how things are tracking.  There are a number of things that make such forecasts possible. Obviously some things like population data are available as a baseline that we can extrapolate from; these tend to be things we already have data on.  It's also a lot easier to forecast things involving natural phenomenon. The only people doing weather forecasts are the meteorologists - nobody thinks a geologist, mineralogist or geochemist can do anything in this area - it's just too complex, too variable and too diverse, and we know it's impossible to reliably predict the weather.  We do know weather influences things like mineralization - we have a weather forecast and we apply probables to mineralization, but its not a weather forecast, its an application of weather probables to a forecast of the mineralization and production.  That leads me to one of the keys in financial forecasting - a lot of it is a function of probables. It's easier to measure than to forecast, that's why we have databases - so we can take all the past data and use it to help make predictions about the future.  We call this databasing, but it's not the key factor in financial forecasting. The key factor in good forecasting - as in good prediction - is understanding what is driving the outcomes  you are trying to forecast.  In the case of mine operations, it's the mineralization and the process - if those things are understood, then the processes  can be replicated.  It's a great place for simulation - the purpose of financial forecasting is to estimate future outcomes.  So if you can simulate the process, your simulations generate future outcomes and you can use all you simulation outputs the future estimates you predict to the current conditions.  In forecasting, all you do is make a future estimate,  that's basically what your simulation is - so it's a case of modelling one simulation for each estimate.  Note when I did this, I used the term "modelling".  That's the other key distinction -  I've defined "financial forecasting" - its making an estimate of what future financial conditions will be. The other term  "financial modelling" is modelling the process for achieving your outcomes.  In a mining sense it's modelling the mining process with mining simulations.  In the financials, I believe you really need to understand your cashflows. In a lot of mining companies, cashflows are seen as a by product of the financial forecasting, and not something they understand.  I believe cashflows should drive your management decisions.  I believe  cashflows should drive the way you plan your mining and processing facilities.  I believe cash flow is a key component of forecasting - in financial forecasting your cashflow is a balance sheet projection, while in the management side, it involves looking at the  the current position and how the money is going to flow.  I believe you need to be managing your financial,  forecasting processes to be doing good cashflow management. A good book to have a look at is Peter Lynch's "100 ways to transform your investment portfolio now". It has the same principles I use for mine management. Lynch is talking in the finance and tax section about  doing financial planning.  He talks about it from an individual's perspective, but its the same principal I used to manage  a mining business. You need to know your current financial position, and what position you want.  These two things will determine the cashflows that you would need to flow past you during each time period you want to achieve that goal. You know you can't have a net income if you have to pay interest and taxes; it ...

# %%
result = get_completion(query="Why do we pay taxes ?", model=model, tokenizer=tokenizer)
print(result)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# <s>
#   Below is an instruction that describes a task. Write a response that appropriately completes the request.
#   ### Question:
#   Why do we pay taxes ?
#
#   ### Answer:
#    If we didn’t the government would not have the money to pay the people it hired  to provide the various services the government is charged with providing. Governments are not profit-driven, and generally do not produce anything that provides a profit. The government will generally provide things (roads, highways, bridges, public schools/universities, sewage lines, etc) that increase your property value, in exchange for an ever-increasing property tax,  and may also provide things (fire departments, police departments, military, etc) that reduce the amount of damage you may suffer at the hands of people that you otherwise could not defend yourself against, in exchange for an ever-increasing income tax.  It’s your choice: pay taxes and get some degree of public services, or decline to pay taxes and pay for those services yourself, or at least accept the risk that someone else is paying for those services and declining to pay for theirs, or the greater risk that nobody is contributing to the cost of those services, and you’re on your own when you need them.  You might think about which of those would give you an outcome you prefer.  Note that generally the tax rate isn’t directly related to your income. Rather, it reflects the cost of government to provide, as the government needs  money to fulfill the service obligations, your share of that cost is likely to be determined in part based on your income. You would just pay the cost directly, without  the tax “subsidy” you would receive from others for the same cost had it been paid in taxes, because the other payers would not be paying it and  it would need to be directly paid, with no benefit from the “subsidy.”  For the government to exist,  it needs someone(s) providing income tax that are worth to those people.  That can be you, but a lot of people choose to get by without paying taxes. Those people’s needs are either being “provided” by private entities, or they don’t have those needs in a reasonable amount to be worth to the government, which would probably mean  that those needs are not being met, either by you directly, or by a private entity that may be receiving money from you that they are using to pay taxes. The government needs you to pay taxes so that the government can provide those services. Your taxing unit (city, county, state, or federal) will provide things they will claim reduce the cost you would pay.  The degree to which this is true  will depend on you and your peers.  You can evaluate a tax as  providing the funding to the government to  provide  you services (at least the services you are paying for, those you’re not, you’re not getting).  You could also evaluate the tax as providing a profit for the  people providing the tax, which the tax is providing,  but it’s not a necessary condition for those people to  have an income.  It’s important you do both evaluations, so that you can understand what the tax is providing for you (service(s) or profit(s)  to the person(s) collecting at least one other (in addition to taxes, either or both) source of income at least  one other income source in addition to taxes). Those in government positions will usually see that you need a service. You (and they) will likely see that you need  to give the government the money as fast as the government can use the money to pay for that service (and  other services to which the government would have otherwise diverted the money from  your tax). That rate will depend on how fast the service is needed (e.g., “immediately” if the government’s services are really needed “right away”, and less than “immediately” if the government’s services can wait a while), how much of the government’s money is in the  government’s hands and can easily be used for this, and how many services the government is providing are equally important to  you for having this service.  The rate of tax you can get away with, or avoid, will reflect the government’s ability to  convince you that you are benef ...
